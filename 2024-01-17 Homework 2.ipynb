# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# alabaster                     0.7.12
# anyio                         3.5.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# atomicwrites                  1.4.0
# attrs                         21.4.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# bagit                         1.8.1
# basemap                       1.3.7
# basemap-data                  1.3.2
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# black                         22.6.0
# bleach                        4.1.0
# bokeh                         2.4.3
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# Cartopy                       0.18.0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("Hello World!")
# Out:
# Hello World!
