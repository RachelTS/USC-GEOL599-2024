# %%
import pandas as pd
import seaborn as sns

# %%
# read the file
file= "C:/Users/rache/Documents/University of Southern California/2023-2024 Year 4/GEOL 599 Environmental data science/data/HW3_LA_AQS_2023.csv"
df= pd.read_csv(file)
df.head()
# Out:
#    State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 0           6           37         1103           68103    1  34.06659
# 1           6           37         1103           42602    3  34.06659
# 2           6           37         1103           62201    1  34.06659
# 3           6           37         1103           62101    1  34.06659
# 4           6           37         1103           42603    1  34.06659
#
#    Longitude  Datum            Parameter Name Duration Description  ... AQI  \
# 0 -118.22688  WGS84   Ambient Min Temperature              24 HOUR  ...   .
# 1 -118.22688  WGS84    Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 2 -118.22688  WGS84         Relative Humidity               1 HOUR  ...   .
# 3 -118.22688  WGS84       Outdoor Temperature               1 HOUR  ...   .
# 4 -118.22688  WGS84  Oxides of nitrogen (NOx)               1 HOUR  ...   .
#
#   Daily Criteria Indicator  Tribe Name  State Name  County Name    City Name  \
# ...

# %%
# print out unique variables in Parameter Name and Duration Description columns
print(df["Parameter Name"].unique()) # "Ozone"
print(df["Duration Description"].unique()) # "1 HOUR"
# Out:
# ['Ambient Min Temperature' 'Nitrogen dioxide (NO2)' 'Relative Humidity'
#  'Outdoor Temperature' 'Oxides of nitrogen (NOx)'
#  'Wind Direction - Scalar' 'Sample Min Baro Pressure'
#  'Wind Direction - Resultant' 'Sample Max Baro Pressure'
#  'Elapsed Sample Time' 'Average Ambient Temperature'
#  'Ambient Max Temperature' 'Ultraviolet radiation' 'Solar radiation'
#  'Sample Flow Rate- CV' 'Wind Speed - Scalar' 'Wind Speed - Resultant'
#  'Average Ambient Pressure' 'Sample Volume' 'Ozone' 'Barometric pressure'
#  'PM2.5 - Local Conditions' 'PM10 Total 0-10um STP' 'Carbon monoxide'
#  'Sulfur dioxide' 'Nitric oxide (NO)' 'NOy - NO'
#  'Reactive oxides of nitrogen (NOy)' 'OC1 CSN_Rev Unadjusted PM2.5 LC'
#  'Sample Volume - Teflon Filter' 'Sample Flow Rate CV - Nylon Filter'
#  'Sample Volume - Nylon Filter' 'Sample Volume - Quartz Filter'
#  'Soil PM2.5 LC' 'Reconstructed Mass PM2.5 LC' 'EC1 PM2.5 LC'
#  'EC2 PM2.5 LC' 'EC3 CSN_Rev Unadjusted PM2.5 LC'
# ...

# %%
# Subset ozone hourly data
df_O3= df[(df["Parameter Name"]== "Ozone") & (df["Duration Description"]== "1 HOUR")]
df_O3.head()
# Out:
#      State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 20            6           37         1103           44201    1  34.06659
# 64            6           37         1103           44201    1  34.06659
# 204           6           37         1103           44201    1  34.06659
# 228           6           37         1103           44201    1  34.06659
# 271           6           37         1103           44201    1  34.06659
#
#      Longitude  Datum Parameter Name Duration Description  ... AQI  \
# 20  -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 64  -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 204 -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 228 -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 271 -118.22688  WGS84          Ozone               1 HOUR  ...   .
#
#     Daily Criteria Indicator  Tribe Name  State Name  County Name  \
# ...

# %%
# Convert the dtype from object to date
df_O3["Date (Local)"] = pd.to_datetime(df_O3["Date (Local)"])
# Out:
# C:\Users\rache\AppData\Local\Temp\ipykernel_6408\4004947214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_O3["Date (Local)"] = pd.to_datetime(df_O3["Date (Local)"])

# %%
# Convert ozone from ppm to ppb
df_O3["Arithmetic Mean"] = df_O3["Arithmetic Mean"]*1000
# Out:
# C:\Users\rache\AppData\Local\Temp\ipykernel_6408\3063353770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_O3["Arithmetic Mean"] = df_O3["Arithmetic Mean"]*1000

# %%
# # See what it looks like using matplotlib.pyplot
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize= (12,6)) #Changes the figure size that is spitted out
# ax.plot(date,value)

# %%
# Plot data with Seaborn
fig = sns.relplot(data= df_O3, x= "Date (Local)", y= "Arithmetic Mean", kind= "line", height= 6, aspect= 1.5)
fig.set(xlabel ="month in 2023", ylabel = "ozone (ppbv)")

# %%
# Find the highest value of O3 in this data subset
df_O3["Arithmetic Mean"].max() # Max is 45.75 ppbv
max_O3 = df_O3[df_O3["Arithmetic Mean"] == 45.75]
print(max_O3["Date (Local)"]) 
### Day of highest ozone is 2023-05-14
# Out:
# 12292   2023-05-14
# Name: Date (Local), dtype: datetime64[ns]

# %%
# Find the number of days O3 exceeded 35 ppbv
df_O3_35plus = df_O3[df_O3["Arithmetic Mean"]>35]
len(df_O3_35plus) 
### There are 43 days where ozone is above 35 ppbv.
# Out:
# 43
